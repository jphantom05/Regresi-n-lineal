# %%
pip install numpy pandas scikit-learn matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # Creación gráficos estadísticos
import matplotlib.pyplot as plt # Creación de gráficos en dos dimensiones


# librerías de para implementar modelos de ciencia de datos
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Cargar el archivo

DatoVehiculo = pd.read_csv(r'D:\Ingenieria de Sistemas\UNAD semestre6\ANÁLISIS DE DATOS\Unidad 2 - Tarea 3\DatasetVehicle\Car_details_v3.csv')

# %%
#Lectura de datos
DatoVehiculo.head(30)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
# Descripción de los datos
DatoVehiculo.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
# Análisis exploratorio de datos

# Variable "año"
plt.figure(figsize=(6, 3))
sns.boxplot(x=DatoVehiculo['year'])

# Variable "precio_de venta"
plt.figure(figsize=(6, 3))
sns.boxplot(x=DatoVehiculo['selling_price'])

# Variable "km_recorridos"
plt.figure(figsize=(6, 3))
sns.boxplot(x=DatoVehiculo['km_driven'])

# Variable "asientos"
plt.figure(figsize=(6, 3))
sns.boxplot(x=DatoVehiculo['seats'])
plt.title('Identificación de Datos Atípicos', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Atípicos')

# %%
2. Preprocesar los datos limpiándolos, tratando valores faltantes y transformándolos según sea necesario

# %%
#Revisión de datos faltantes

print("Cantidad de Registros con cero en year: ",DatoVehiculo['year'].isin([0]).sum())
print("Cantidad de Registros con cero en selling_price: ",DatoVehiculo['selling_price'].isin([0]).sum())
print("Cantidad de Registros con cero en km_driven: ",DatoVehiculo['km_driven'].isin([0]).sum())
print("Cantidad de Registros con cero en mileage: ",DatoVehiculo['mileage'].isin([0]).sum())
print("Cantidad de Registros con cero en seats: ",DatoVehiculo['seats'].isin([0]).sum())
# Out:
# Cantidad de Registros con cero en year:  0
# Cantidad de Registros con cero en selling_price:  0
# Cantidad de Registros con cero en km_driven:  0
# Cantidad de Registros con cero en mileage:  0
# Cantidad de Registros con cero en seats:  0

# %%
# Contar valores nulos en cada columna
nulos = DatoVehiculo.isnull().sum()
print("Cantidad de valores nulos en cada columna:\n", nulos)
# Out:
# Cantidad de valores nulos en cada columna:
#  name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
# Definir límites para datos atípicos
max_asientos = 16
min_asientos = 2
total_asientos = ((DatoVehiculo['seats'] < min_asientos) | (DatoVehiculo['seats'] > max_asientos)).sum()

max_ano = 2024
min_ano = 1980
total_ano = ((DatoVehiculo['year'] < min_ano) | (DatoVehiculo['year'] > max_ano)).sum()

print("Total registros dataset: {}".format(len(DatoVehiculo)))
print("El total de datos atípicos para la cantidad de asientos es {}".format(total_asientos))
print("El total de datos atípicos para el año es {}".format(total_ano))
print("")
DatoVehiculo.info()
# Out:
# Total registros dataset: 8128
# El total de datos atípicos para la cantidad de asientos es 0
# El total de datos atípicos para el año es 0
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
3. Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características.

# %%
# Crear una copia del DataFrame
data_numerica = DatoVehiculo.copy()

# Convertir columnas de tipo object a numéricas
for column in data_numerica.columns:
    if data_numerica[column].dtype == 'object':
        label_encoder = LabelEncoder()
        data_numerica[column] = label_encoder.fit_transform(data_numerica[column])

# Verificar el resultado
print(data_numerica.head())
# Out:
#    name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0  1307  2014         450000     145500     1            1             1
# 1  1607  2014         370000     120000     1            1             1
# 2   385  2006         158000     140000     3            1             1
# 3   781  2010         225000     127000     1            1             1
# 4  1349  2007         130000     120000     3            1             1
#
#    owner  mileage  engine  max_power  torque  seats
# 0      0      335      13        244     178    5.0
# 1      2      284      36         15     260    5.0
# 2      4      180      35        253      66    5.0
# 3      0      327      24        297     224    5.0
# 4      0      136      14        288      21    5.0

# %%
4. Dividir el dataset en Train y Test para evaluar correctamente el modelo.

# %%
# Dividir los datos en conjunto de entrenamiento y prueba
X = data_numerica.drop('selling_price', axis=1)
Y = data_numerica['selling_price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
#Validar datos en train
X_train.head()
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 4313   704  2012      40000     3            1             1      0      251
# 5178  1464  2007     120000     3            1             0      0       23
# 758    500  2013      80000     3            1             1      2      281
# 7117   117  2016     100000     1            1             1      0       64
# 2606  1338  2013      77000     1            1             1      0      325
#
#       engine  max_power  torque  seats
# 4313      10        255      32    5.0
# 5178      51        128     240    5.0
# 758      114        191     407    5.0
# 7117      89        236     147    9.0
# 2606      13        244     178    5.0

# %%
#Validar datos en test
X_test.head()
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 3558   776  2013      40000     1            1             1      0      305
# 233    976  2013      70000     1            1             1      0       46
# 7952  1258  2019       5000     3            1             0      0      299
# 572   1391  2004     120000     3            1             1      4      210
# 6960   809  2019      20000     3            0             0      0      315
#
#       engine  max_power  torque  seats
# 3558      24        294     221    5.0
# 233       95        103     315    7.0
# 7952     119        220     425    5.0
# 572      119        224     424    5.0
# 6960      83        153     197    5.0

# %%
# Imputar NaN en X_train usando la media de las columnas
X_train.fillna(X_train.mean(), inplace=True)
# Imputar NaN en X_test usando la media de las columnas
X_test.fillna(X_train.mean(), inplace=True)

# %%
5. Entrenar el modelo configurando los diferentes hiperparámetros.

# %%
# Crear y entrenar el modelo de regresión lineal
modelo_regresion = LinearRegression()
modelo_regresion.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Realizar predicciones
Prediccion = modelo_regresion.predict(X_test)

# %%
print("Cantidad de valores nulos en X_test:", X_test.isnull().sum().sum())
print("Cantidad de valores nulos en X_train:", X_train.isnull().sum().sum())
# Out:
# Cantidad de valores nulos en X_test: 0
# Cantidad de valores nulos en X_train: 0

# %%
6. Evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc.

# %%
# Evaluar el modelo
print('Coeficientes:', modelo_regresion.coef_)
print('Error cuadrático medio:', mean_squared_error(Y_test, Prediccion))
print('Coeficiente de determinación (R^2):', r2_score(Y_test, Prediccion))
# Out:
# Coeficientes: [-1.00605785e+02  6.70212282e+04 -7.24630486e-01 -2.04623211e+05
#  -3.05270598e+05 -9.90911039e+05 -1.50242959e+04 -1.86704345e+03
#   1.41673474e+03  1.14463700e+02  6.34645932e+02 -9.45187167e+04]
# Error cuadrático medio: 321945582279.3761
# Coeficiente de determinación (R^2): 0.5124824447265901

# %%
7. Realizar las diferentes gráficas que permitan visualizar los resultados del modelo.

# %%
# Visualizar el rendimiento del modelo
plt.scatter(Y_test, Prediccion)
plt.xlabel("Valores reales")
plt.ylabel("Predicciones")
plt.title("Rendimiento del modelo de regresión lineal")
plt.show()
